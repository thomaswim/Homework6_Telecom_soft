# %%
import requests
r = requests.get("https://ffn.extranat.fr/webffn/nat_recherche.php?idact=nat")
print(r.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# 	<meta http-equiv="Content-Type" content="text/html; charset=utf8">
# 	<meta name="author" content="Olivier Dupas">
# 	<title>F&eacute;d&eacute;ration Fran&ccedil;aise de Natation</title>
# 	<script language="JavaScript" src="../media/js/webffn.js" type="text/JavaScript"></script>
# 	<link rel="alternate" type="application/rss+xml" title="RSS" href="http://www.ffnatation.fr/html/news/0_rss.xml"></link>
# 	<link rel="stylesheet" type="text/css" href="../media/css/natation.css?jeton=5">
# 	<link rel="stylesheet" type="text/css" href="../media/css/style_natation.css?jeton=5">
# 	<link rel="stylesheet" type="text/css" href="../media/css/jquery-ui.min.css?jeton=5"></link>
# 	<link rel="stylesheet" type="text/css" href="../media/css/font-awesome/css/font-awesome.min.css?jeton=5"></link>
# ...

# %%
import requests
r = requests.request('POST',"https://ffn.extranat.fr/webffn/nat_recherche.php?idact=nat")
print(r.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# 	<meta http-equiv="Content-Type" content="text/html; charset=utf8">
# 	<meta name="author" content="Olivier Dupas">
# 	<title>F&eacute;d&eacute;ration Fran&ccedil;aise de Natation</title>
# 	<script language="JavaScript" src="../media/js/webffn.js" type="text/JavaScript"></script>
# 	<link rel="alternate" type="application/rss+xml" title="RSS" href="http://www.ffnatation.fr/html/news/0_rss.xml"></link>
# 	<link rel="stylesheet" type="text/css" href="../media/css/natation.css?jeton=5">
# 	<link rel="stylesheet" type="text/css" href="../media/css/style_natation.css?jeton=5">
# 	<link rel="stylesheet" type="text/css" href="../media/css/jquery-ui.min.css?jeton=5"></link>
# 	<link rel="stylesheet" type="text/css" href="../media/css/font-awesome/css/font-awesome.min.css?jeton=5"></link>
# ...

# %%
import requests
r = requests.request('HEAD',"https://httpbin.org/head")
print(r.text)

# %%
import requests
r = requests.request('PUT',"https://httpbin.org/put")
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-63905f2c-0cbe9bf92776707e0236fde9"
#   },
#   "json": null,
#   "origin": "87.110.55.153",
#   "url": "https://httpbin.org/put"
# }

# %%
import requests
r = requests.request('PATCH',"https://httpbin.org/patch")
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-63905f2c-5732ffe950d90c3c026c464c"
#   },
#   "json": null,
#   "origin": "87.110.55.153",
#   "url": "https://httpbin.org/patch"
# }

# %%
import requests
r = requests.request('delete',"https://httpbin.org/delete")
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-63905f2e-02af8a1a2b83d8fd4a1e86ae"
#   },
#   "json": null,
#   "origin": "87.110.55.153",
#   "url": "https://httpbin.org/delete"
# }

# %%
import requests
r = requests.get("https://ffn.extranat.fr/webffn/nat_recherche.php?idact=nat")
type(r)

print(r.headers)
print(r.encoding)
print(r.apparent_encoding)
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'Content-Length': '6353', 'Connection': 'keep-alive', 'Date': 'Wed, 07 Dec 2022 09:38:50 GMT', 'Server': 'Apache', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 6ae82cc0c8a39c993134c2be90b4d120.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'FRA60-P3', 'X-Amz-Cf-Id': 'x8BiAXTm6k8v4U1AjawAXsPrX2PzKaEF5YEUD4G1AVmeikYWYdIYZw==', 'Age': '6'}
# UTF-8
# utf-8

# %%
import requests
payload = {'key1': 'value1', 'key2': 'value2'}

r = requests.post("https://httpbin.org/post", data=payload)

print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-63905f32-4d72e3f033c7db0b2d2fc54d"
#   },
#   "json": null,
#   "origin": "87.110.55.153",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests
fs = {'file':open('test.txt','rb')}
r=requests.request('POST','https://httpbin.org/post',files=fs)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {
#     "file": "Its a test don't worry\n"
#   },
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "167",
#     "Content-Type": "multipart/form-data; boundary=d5065bb36b99c8b1659b9217e848eb2e",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-63905f4f-0c62308a6b743c097ba71b4f"
#   },
#   "json": null,
#   "origin": "87.110.55.153",
#   "url": "https://httpbin.org/post"
# }

# %%
# Example 2

import requests
url="https://www.alibaba.com/trade/search?fsb=y&IndexArea=product_en&CatId=&tab=all&SearchText=socket"

try:
    kv={'user-agent':'Mozilla/5.0'}
    r=requests.get(url,headers = kv)
    r.raise_for_status()
    r.encoding = r.apparent_encoding
    print(r.text[:2000])
except:
    print('anomali')
    
print(r.status_code)
print(r.encoding)
# Out:
#     <!-- tangram:4926 begin-->
#
#
#
# <!DOCTYPE html>
# <html class="rwd" >
# <head>
#     <script>
#         window.__BB = window.__BB || {
#           // 关闭本地存储功能
#           disableStore: true,
#           // 自动上报
#           autoReportAPI: true,
#           // 主动上报性能
#           autoReportPerf: true,
#           // 打点模式 (0: 自动打点，1: 不打点，-1: 轮询模式)
#           mode: -1,
#           // 应用标识
#           token: "3c5d1b712654492388240c69a6fc9655",
#           // 关联的场景 id
#           scene: "pc-search-all"
#         };
#                 window.__setBBParams = function(keyName, timeVal){
#             if( typeof(Performance) != 'undefined' ){
#                 window.__BB['extendParams'] = window.__BB['extendParams'] || {};
#                 timeVal = timeVal || new Date().getTime() - performance.timing.navigationStart;
#                 window.__BB['extendParams'][keyName]= timeVal;
#             }
#         };
#         window.__setBBParams('time1');
#         // 暂时去掉 umid 加载
# ...

# %%
# Example 2

import requests

keyword='Christmas socket'


try:
    kv={'q':keyword}
    r=requests.get("http://www.google.com/search",params = kv)
    print(r.request.url)
    r.raise_for_status()
    print(r.text)
except:
    print('anomali')
    
print(r.status_code)
print(r.encoding)
# Out:
# http://www.google.com/search?q=Christmas+socket
# <!doctype html><html lang="lv"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Christmas socket - Google mekl&#275;&#353;ana</title><script nonce="4M78rq-OeXrUsSXi54JFRA">(function(){
# ...

# %%
# Example 3

import requests
import os


url = 'https://cdn.shopify.com/s/files/1/0234/4461/products/beer-christmas-sweater-mens-socks_1600x.jpg?v=1668064473'

path = os.getcwdb()
print(path)
try:
    with open(path,"wb") as f:
        print("ss")
        f.write(r.content)
        f.close()
        print("file save succesfully")
except:
    print('Problem')
# Out:
# b'/home/boubou/Documents/Telecom Soft/HW6'
# Problem

# %%
import requests
from bs4 import BeautifulSoup

def getdata(url):
    r = requests.get(url)
    return r.text

htmldata = getdata('https://www.amazon.com/christmas-socks/s?k=christmas+socks')
soup = BeautifulSoup(htmldata, 'html.parser')
for item in soup.find_all('img'):
    print(item['src'])
